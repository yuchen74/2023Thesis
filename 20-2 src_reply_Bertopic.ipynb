# %% [markdown]
# # Load library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install bertopic
from bertopic import BERTopic

# %%
# from google.colab import drive
# import os
# drive.mount('/content/drive')

# %% [markdown]
# # Bertopic

# %%
combined_data = pd.read_csv('combined_rumor_target.csv',header = 0,index_col = 0,encoding = 'utf-8')

# %% [markdown]
# ## Rumor Source tweets
#
# [report](https://docs.google.com/spreadsheets/d/1iWx_pUEnssY3wUK11iJSiqdn7iZQAGxn0dofwTdludY/edit?usp=sharing)

# %%
src = combined_data[combined_data.src_reply=='src']
src.isnull().sum()
# Out:
# tweet_id        0
# user_id         0
# tweet           0
# cleaned_text    0
# targetlabel     0
# date            0
# rumorlabel      0
# sentiment       0
# src_reply       0
# dtype: int64

# %%
target_docs = src.loc[src.targetlabel ==1,'cleaned_text'].to_list()
nontarget_docs = src.loc[src.targetlabel ==0,'cleaned_text'].to_list()

# %%
print("# of target tweets: {}".format(len(target_docs)) )
print("# of non-target tweets: {}".format(len(nontarget_docs)) )
# Out:
# # of target tweets: 36
# # of non-target tweets: 408

# %%
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics=10)

# %% [markdown]
# ### topics of target tweets

# %%
topics, probs = topic_model.fit_transform(target_docs)
# Out:
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# 2022-12-22 15:10:59,619 - BERTopic - Transformed documents to Embeddings
# 2022-12-22 15:11:03,372 - BERTopic - Reduced dimensionality
# 2022-12-22 15:11:03,392 - BERTopic - Clustered reduced embeddings
# 2022-12-22 15:11:03,563 - BERTopic - Reduced number of topics from 3 to 3

# %%
topic_model.get_topic_freq().sort_values(['Topic'])
# Out:
#    Topic  Count
# 2     -1     10
# 0      0     14
# 1      1     12

# %%
topic_words = topic_model.get_topics()
topiclist = []
for topic in range(2):
  wordlist = []
  for words in range(10):
        wordlist.append(topic_words[topic][words][0])
  topiclist.append(wordlist)

# %%
df = pd.DataFrame(topiclist)

# %%
df
# Out:
#          0             1       2       3       4       5      6        7  \
# 0  suspect        french  police  martyr     say     die   want     tell
# 1    akbar  charliehebdo   shout  allahu  gunmen  attack  video  witness
#
#         8        9
# 0   hebdo  charlie
# 1  report    shoot

# %%
fig = topic_model.visualize_barchart(n_words=10,top_n_topics=10)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="421c06c6-70c3-44c8-a28b-55bf7d7e94af" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("421c06c6-70c3-44c8-a28b-55bf7d7e94af")) {                    Plotly.newPlot(                        "421c06c6-70c3-44c8-a28b-55bf7d7e94af",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.014062530610168393,0.014923698175849057,0.0151235873192255,0.015903905135146522,0.01605481077945216,0.016593321046330062,0.031029206172113015,0.03942006918651735,0.07428584443928847,0.09257054790149548],"y":["immigration  ","arm  ","attack  ","guillotine  ","country  ","gun  ","paris  ","police  ","french  ","france  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.030810942567752003,0.033337888059710566,0.03368910436098561,0.03438826447580178,0.03465595708913913,0.0360050544937019,0.042161836748682,0.060531185412195286,0.06316297608229073,0.1289538360866473],"y":["suspect  ","shout  ","police  ","french  ","paris  ","attack  ","gunmen  ","charlie  ","hebdo  ","charliehebdo  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02406508297645432,0.02427342688802128,0.024865098178792573,0.02501252955173236,0.025545281548044342,0.025786309768793397,0.02871708713824627,0.0289808898471155,0.046169379392798,0.09543259722118838],"y":["use  ","act  ","evil  ","muslims  ","people  ","stop  ","name  ","fuck  ","religious  ","religion  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.021802406828168353,0.025853056024526803,0.027015489770136396,0.02745830468948338,0.03699708941766958,0.03818485344899641,0.03818768771425627,0.061991980991109336,0.1182696698102243,0.1203948122012491],"y":["course  ","people  ","others  ","press  ","block  ","expression  ","respect  ","free  ","speech  ","freedom  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.023226563107232045,0.025556810123591067,0.025556810123591067,0.027083970670409258,0.0312146257630189,0.03249966900858638,0.03249966900858638,0.052722684590782616,0.0852908619796562,0.14522540837240802],"y":["kill  ","arabs  ","palestinian  ","israels  ","zionist  ","israeli  ","palestine  ","hamas  ","gaza  ","israel  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.03858545931665265,0.03868587720205617,0.03986657648793797,0.0407681496929625,0.044708271857595294,0.055929028744340435,0.06588534586906389,0.07066492500567172,0.07162118767735452,0.08265152565723859],"y":["isis  ","muslim  ","nt  ","muslims  ","terrorists  ","terrorist  ","terrorism  ","attack  ","denounce  ","islam  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.03421806796977229,0.03610617070027878,0.04351387664395457,0.04624533438014981,0.058630232394588554,0.060463954019884546,0.06051251238695374,0.06308417438106936,0.06474346813220974,0.06683397989132807],"y":["putin  ","army  ","russia  ","iraq  ","afghanistan  ","middle  ","oil  ","syria  ","east  ","war  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03011818348776279,0.030617717788683694,0.03207073396560194,0.03955398433245576,0.04005250145759711,0.04088155462600922,0.042045074719456274,0.051353093997224646,0.05210651254261735,0.05659203095865541],"y":["get  ","justify  ","incompetence  ","people  ","murder  ","no  ","trial  ","punishment  ","kill  ","innocent  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.059975504790271965,0.06086462621185317,0.06353047575502549,0.0671204026593787,0.0671204026593787, ...

# %% [markdown]
# ### topics of non-targets

# %%
topics, probs = topic_model.fit_transform(nontarget_docs)
# Out:
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]
# 2022-12-22 15:17:24,282 - BERTopic - Transformed documents to Embeddings
# 2022-12-22 15:17:27,740 - BERTopic - Reduced dimensionality
# 2022-12-22 15:17:27,782 - BERTopic - Clustered reduced embeddings
# 2022-12-22 15:17:27,880 - BERTopic - Reduced number of topics from 2 to 2

# %%
topic_model.get_topic_freq().sort_values(['Topic'])
# Out:
#    Topic  Count
# 1      0     27
# 0      1    381

# %%
topic_words = topic_model.get_topics()
topiclist = []
for topic in range(2):
  wordlist = []
  for words in range(10):
        wordlist.append(topic_words[topic][words][0])
  topiclist.append(wordlist)

# %%
nontarget_df = pd.DataFrame(topiclist)

# %%
nontarget_df
# Out:
#         0              1        2             3         4       5        6  \
# 0  banksy  jesuischarlie  banksys  charliehebdo  powerful    isnt  tribute
# 1   paris   charliehebdo   police       suspect     break  attack   french
#
#           7      8       9
# 0  response    not  attack
# 1      kill  shoot  report

# %%
nontarget_fig = topic_model.visualize_barchart(n_words=10,top_n_topics=10)
nontarget_fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9a828df5-0321-46aa-b1dc-573ce16c7e1f" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a828df5-0321-46aa-b1dc-573ce16c7e1f")) {                    Plotly.newPlot(                        "9a828df5-0321-46aa-b1dc-573ce16c7e1f",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.12343916605607076,0.1377671817143241,0.1377671817143241,0.14285657696593104,0.14285657696593104,0.14285657696593104,0.23225701189508804,0.25411459211912885,0.3297813113264013,0.5046649361915556],"y":["attack  ","not  ","response  ","tribute  ","isnt  ","powerful  ","charliehebdo  ","banksys  ","jesuischarlie  ","banksy  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.06042392311726691,0.06287347429372907,0.06527211904243425,0.06586415972924237,0.07167636504139427,0.07580913533005941,0.07766700773974868,0.09088794912126884,0.10325424940267776,0.12874623595045437],"y":["report  ","shoot  ","kill  ","french  ","attack  ","break  ","suspect  ","police  ","charliehebdo  ","paris  "],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778," ...

# %% [markdown]
# ## Rumor Reply tweets
#
# [report](https://docs.google.com/spreadsheets/d/1iWx_pUEnssY3wUK11iJSiqdn7iZQAGxn0dofwTdludY/edit?usp=sharing)

# %%
reply = combined_data[combined_data.src_reply=='reply']
reply.isnull().sum()
# Out:
# tweet_id        0
# user_id         0
# tweet           0
# cleaned_text    0
# targetlabel     0
# date            0
# rumorlabel      0
# sentiment       0
# src_reply       0
# dtype: int64

# %%
target_docs = reply.loc[reply.targetlabel ==1,'cleaned_text'].to_list()
nontarget_docs = reply.loc[reply.targetlabel ==0,'cleaned_text'].to_list()

# %%
print("# of target tweets: {}".format(len(target_docs)) )
print("# of non-target tweets: {}".format(len(nontarget_docs)) )
# Out:
# # of target tweets: 2361
# # of non-target tweets: 3818

# %%
from bertopic import BERTopic

topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics="auto")

# %% [markdown]
# ### topics of target tweets

# %%
topics, probs = topic_model.fit_transform(target_docs)
# Out:
# Batches:   0%|          | 0/74 [00:00<?, ?it/s]
# 2022-12-22 15:22:37,303 - BERTopic - Transformed documents to Embeddings
# 2022-12-22 15:22:51,901 - BERTopic - Reduced dimensionality
# 2022-12-22 15:22:52,368 - BERTopic - Clustered reduced embeddings
# 2022-12-22 15:22:54,046 - BERTopic - Reduced number of topics from 42 to 13

# %%
topic_model.get_topic_freq().sort_values(['Topic'])
# Out:
#     Topic  Count
# 0      -1    900
# 1       0    900
# 2       1    194
# 3       2    112
# 4       3     87
# 5       4     33
# 6       5     31
# 7       6     26
# 8       7     24
# 9       8     18
# 10      9     14
# 11     10     12
# 12     11     10

# %%
topic_words = topic_model.get_topics()
topiclist = []
for topic in range(12):
  wordlist = []
  for words in range(10):
        wordlist.append(topic_words[topic][words][0])
  topiclist.append(wordlist)

# %%
df = pd.DataFrame(topiclist)

# %%
df
# Out:
#                0            1           2        3        4          5  \
# 0            not         kill    religion   people  muslims      islam
# 1         france       french          le   police       de      paris
# 2         israel         jews        gaza    never    hamas       kill
# 3   charliehebdo        hebdo     charlie   attack    paris     police
# 4            que           de          la      por       el         se
# 5          tweet      twitter  understand     fake   victim        not
# 6         kosher  supermarket       store  grocery   jewish  synagogue
# 7       trkiyede           ss         kii    kaide    koavi  tmgeneral
# 8         banksy      banksys     account     gogh  lucille      clerc
# 9            het         niet         dit       ik      dat      belga
# 10       virgins        goats          ok   reward   heaven     virgin
# 11        mosque      mosques         aix    bains    savoy    condone
#
#          6          7      8            9
# 0       no  terrorist  peace          say
# 1      les         la    pas           je
# 2      not     people   anti         dont
# 3     dead     french     mt    satirical
# 4     como        los     en           lo
# 5    check        mam  reply  information
# 6   market       mean   bury   jesuisjuif
# 7      var   israilli   aviv           el
# 8      fan        van    not         draw
# 9      zou        bij    uit         toch
# 10  theyll         no   hell      bakhaad
# 11    burn        via    les      country

# %%
fig = topic_model.visualize_barchart(n_words=10,top_n_topics=10)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="15827787-4e52-4b71-b496-1f99ba5b7566" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15827787-4e52-4b71-b496-1f99ba5b7566")) {                    Plotly.newPlot(                        "15827787-4e52-4b71-b496-1f99ba5b7566",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01879037436368433,0.019528011415955376,0.020398573440801163,0.022453253735886712,0.024212609747857217,0.024602182223220873,0.02895502402187326,0.030548989201044093,0.030724126135881435,0.03640905956283515],"y":["say  ","peace  ","terrorist  ","no  ","islam  ","muslims  ","people  ","religion  ","kill  ","not  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02495055233458575,0.027933539309527407,0.02951123049106209,0.031658988239380646,0.033849090112980054,0.03410252937839242,0.041330260239649516,0.04470684693985307,0.07871747139708786,0.0991840139603307],"y":["je  ","pas  ","la  ","les  ","paris  ","de  ","police  ","le  ","french  ","france  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.029601731134651078,0.030142963665219034,0.030389405354275995,0.0319785070098279,0.03409739304784732,0.0435900826080704,0.05791688080898227,0.06838648232567926,0.1041295209242309,0.14387545709401986],"y":["dont  ","anti  ","people  ","not  ","kill  ","hamas  ","never  ","gaza  ","jews  ","israel  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.03743001797983012,0.03743001797983012,0.04136650926049395,0.04762366052575033,0.04826511722093124,0.04891673164302928,0.053251385849582875,0.08639523030294093,0.09256631818172241,0.24819905556296368],"y":["satirical  ","mt  ","french  ","dead  ","police  ","paris  ","attack  ","charlie  ","hebdo  ","charliehebdo  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.060303160396120936,0.06951885349857985,0.07956155935845971,0.08516254020556362,0.09690846593547883,0.09905295833595384,0.1107525324976901,0.11088456551352224,0.1287488567584793,0.16989730631069092],"y":["lo  ","en  ","los  ","como  ","se  ","el  ","por  ","la  ","de  ","que  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.05064439010659495,0.055880689036795356,0.06237688713109251,0.06237688713109251,0.06776290675533249,0.07097040506153683,0.07812857274099752,0.07996597880291115,0.12661097526648737,0.4819700458420909],"y":["information  ","reply  ","mam  ","check  ","not  ","victim  ","fake  ","understand  ","twitter  ","tweet  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.08262681622568885,0.08798858913193844,0.09101676661324623,0.10715816317256349,0.1182376168692458,0.14943035979659194,0.16685095229699057,0.19302804792889453,0.22151879537616434,0.5708741633844833],"y":["jesuisjuif  ","bury  ","mean  ","market  ","synagogue  ","jewish  ","grocery  ","store  ","supermarket  ","kosher  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.07776885158607948,0.0946909130187023,0.09836848565981332,0.09836848565981332,0.09836848565981332,0.09836848565981332,0.09836848565981332,0.09836848565981332,0.09836848565981332,0.09836848565981332],"y":["el  ","aviv  ","israilli  ","var  ","tmgeneral  ","koavi  ","kaide  ","kii  ","ss  ","trkiyede  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.07833568642107919,0.09201684332623018,0.10226761680392636,0.10890390949936643,0.10890390949936643,0.10890390949936643,0.10890390949936643,0.1878295159879177,0.23478689498489708,0.501354112888946 ...

# %% [markdown]
# ### topics of non-targets

# %%
topics, probs = topic_model.fit_transform(nontarget_docs)
# Out:
# Batches:   0%|          | 0/120 [00:00<?, ?it/s]
# 2022-12-22 15:30:02,566 - BERTopic - Transformed documents to Embeddings
# 2022-12-22 15:30:27,836 - BERTopic - Reduced dimensionality
# 2022-12-22 15:30:29,410 - BERTopic - Clustered reduced embeddings
# 2022-12-22 15:30:33,999 - BERTopic - Reduced number of topics from 90 to 61

# %%
topic_model.get_topic_freq().sort_values(['Topic']).head(11)
# Out:
#     Topic  Count
# 0      -1   1439
# 1       0    755
# 2       1    117
# 3       2     96
# 4       3     83
# 5       4     60
# 6       5     51
# 7       6     48
# 8       7     46
# 9       8     40
# 10      9     38

# %%
topic_words = topic_model.get_topics()
topiclist = []
for topic in range(10):
  wordlist = []
  for words in range(10):
        wordlist.append(topic_words[topic][words][0])
  topiclist.append(wordlist)

# %%
nontarget_df = pd.DataFrame(topiclist)

# %%
nontarget_df
# Out:
#           0        1         2             3           4               5  \
# 0     paris   french    france  charliehebdo       break           tweet
# 1     islam   muslim   muslims         allah     nothing         islamic
# 2  hostages  hostage      pray         women        hope             two
# 3      dont      say     doubt          word  understand             get
# 4  religion    peace    strike      peaceful         god         prophet
# 5     irony    think  ignorant     brainwash     process            talk
# 6       gun   police       cop     policeman     officer             man
# 7        oh      wow       smh          dear         wth              hi
# 8      safe     fear      stay        crisis     tragedy         missile
# 9    source   please    follow        oblige       nicki  understatement
#
#             6           7          8             9
# 0        news     charlie       kill        police
# 1    muhammad          im    billion          know
# 2  situations  terrorists      storm          news
# 3      offend         not  relevance            no
# 4       piece      agenda      facts       believe
# 5        mean      ironic     morons           lot
# 6   policemen       shoot      carry   policewoman
# 7          kk        duhh       damm            gh
# 8       cuban      afraid  necessary          risk
# 9    sourceon      philly    stinkin  followfriday

# %%
nontarget_fig = topic_model.visualize_barchart(n_words=10,top_n_topics=10)
nontarget_fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4fcab7e0-2d27-489f-bb24-2aee6829cf00" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fcab7e0-2d27-489f-bb24-2aee6829cf00")) {                    Plotly.newPlot(                        "4fcab7e0-2d27-489f-bb24-2aee6829cf00",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.011484198158057766,0.01252495153905916,0.013295631213467307,0.01383378794455185,0.015053052150844867,0.015371825658018092,0.01601326963728277,0.018357018320471756,0.020822055958896264,0.023913118628813956],"y":["police  ","kill  ","charlie  ","news  ","tweet  ","break  ","charliehebdo  ","france  ","french  ","paris  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.015897556116739858,0.0160171535536575,0.016416914223593426,0.01704502036709116,0.017523493958265805,0.021559660543386244,0.027114579028034436,0.08235767850349315,0.08504214860101991,0.09154557996243798],"y":["know  ","billion  ","im  ","muhammad  ","islamic  ","nothing  ","allah  ","muslims  ","muslim  ","islam  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.020921469422316066,0.0211417114796838,0.022469079373139335,0.02444007753602644,0.028117941425164727,0.028966455533125875,0.03171256721952569,0.035017462609983833,0.08375623596402566,0.13198234579892232],"y":["news  ","storm  ","terrorists  ","situations  ","two  ","hope  ","women  ","pray  ","hostage  ","hostages  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.029450201071844904,0.031062306853185864,0.034710357967929435,0.03491503188532256,0.04004364092223789,0.046506502495920934,0.051868568949250134,0.05528835732351519,0.07023573092303105,0.08828285606848309],"y":["no  ","relevance  ","not  ","offend  ","get  ","understand  ","word  ","doubt  ","say  ","dont  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.03131699015029785,0.03400453383021249,0.03400453383021249,0.03578025430938007,0.03704999079820419,0.03718200241876146,0.04178464869062585,0.04341060374604465,0.07601062773526863,0.14761032981570127],"y":["believe  ","facts  ","agenda  ","piece  ","prophet  ","god  ","peaceful  ","strike  ","peace  ","religion  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.029666773386958445,0.030265837446693918,0.030265837446693918,0.03088274726394987,0.0328133295083406,0.032845922944892685,0.03736511854065581,0.048145758915163706,0.06948097148394011,0.07473023708131162],"y":["lot  ","morons  ","ironic  ","mean  ","talk  ","process  ","brainwash  ","ignorant  ","think  ","irony  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.028080705913690683,0.03050454256480268,0.03140505836381034,0.032430151768375055,0.034208596912060185,0.06586334153137192,0.0667177562491511,0.06717828919707632,0.09438121081163296,0.11847894711904677],"y":["policewoman  ","carry  ","shoot  ","policemen  ","man  ","officer  ","policeman  ","cop  ","police  ","gun  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.08426276133079806,0.08426276133079806,0.08426276133079806,0.08426276133079806,0.10885128102558751,0.12860149374965588,0.12860149374965588,0.17552983253835444,0.19039857521654044,0.46719749065768423],"y":["gh  ","damm  ","duhh  ","kk  ","hi  ","wth  ","dear  ","smh  ","wow  ","oh  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.04015159759604641,0.04637071474573085,0.052750755586808196,0.06409236165182242,0.06409236165182242,0.07307124250465434,0.07307124250465434 ...
